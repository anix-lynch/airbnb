# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             line-height: 1.6;
#         }
#         .assignment {
#             background-color: #f8f9fa;
#             border-left: 5px solid #007bff;
#             padding: 20px;
#             margin: 20px 0;
#             border-radius: 5px;
#         }
#         h2 {
#             color: #007bff;
#         }
#         ul {
#             list-style-type: none;
#         }
#         li {
#             margin-bottom: 10px;
#         }
#         .highlight {
#             color: #dc3545;
#         }
#     </style>
# </head>
# <body>
#     <div class="assignment">
#         <h2>Assignment</h2>
#         <p>A new city manager for Airbnb has started in Dublin and wants to better understand:</p>
#         <ul>
#             <li>🔍 <span class="highlight">what guests are searching for in Dublin,</span></li>
#             <li>💼 <span class="highlight">which inquiries hosts tend to accept.</span></li>
#         </ul>
#         <p>Based on the findings, the new city manager will try to boost the number and quality of hosts in Dublin to fit the demands from guests. The goal of this challenge is to <span class="highlight">analyze, understand, visualize,</span> and <span class="highlight">communicate</span> the demand/supply in the market. For example, you may want to look at the breakdown of start date day of the week, or number of nights, or room type that is searched for, and how many hosts accepted the reservation. In particular, we are interested in:</p>
#         <ul>
#             <li>🔍 <span class="highlight">what the gaps are between guest demand and host supply that the new city manager could plug to increase the number of bookings in Dublin,</span></li>
#             <li>📊 <span class="highlight">what other data would be useful to have to deepen the analysis and understanding.</span></li>
#         </ul>
#     </div>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# </head>
# <body>
#     <h2 style="color: #FF9900;">Anix's Social Media Links</h2>
#     <div style="display: flex; flex-wrap: wrap; gap: 10px; margin-top: 20px;">
#         <a href="https://www.linkedin.com/in/anixlynch/" style="display: inline-block;">
#             <img src="https://raw.githubusercontent.com/anix-lynch/logo/main/linkedin.png" alt="LinkedIn" style="width: 30px; height: 30px; border-radius: 5px; margin: 5px;">
#         </a>
#         <a href="mailto:alynch@alumni.chicagobooth.edu" style="display: inline-block;">
#             <img src="https://raw.githubusercontent.com/anix-lynch/logo/main/gmail.png" alt="Gmail" style="width: 30px; height: 30px; border-radius: 5px; margin: 5px;">
#         </a>
#         <a href="https://github.com/anix-github" style="display: inline-block;">
#             <img src="https://raw.githubusercontent.com/anix-lynch/logo/main/github.png" alt="GitHub" style="width: 30px; height: 30px; border-radius: 5px; margin: 5px;">
#         </a>
#         <a href="https://x.com/anixlynch" style="display: inline-block;">
#             <img src="https://raw.githubusercontent.com/anix-lynch/logo/main/twitter.png" alt="Twitter" style="width: 30px; height: 30px; border-radius: 5px; margin: 5px;">
#         </a>
#         <a href="https://www.kaggle.com/anixlynch" style="display: inline-block;">
#             <img src="https://raw.githubusercontent.com/anix-lynch/logo/main/kaggle.png" alt="Kaggle" style="width: 30px; height: 30px; border-radius: 5px; margin: 5px;">
#         </a>
#         <a href="https://anixlynch.com" style="display: inline-block;">
#             <img src="https://raw.githubusercontent.com/anix-lynch/logo/main/internet.png" alt="Website" style="width: 30px; height: 30px; border-radius: 5px; margin: 5px;">
#         </a>
#     </div>
# </body>
# </html>

# %%
import os

# List contents of the current directory
os.listdir(".")
# Out:
# ['Icon\r',
#  'searches.tsv',
#  'Untitled.ipynb',
#  'acceptance_rate_by_country.csv',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  'airtbnbQ.pdf',
#  'nba.py',
#  'Airbnb_Data_Analysis.ipynb',
#  'airbnb.py',
#  'contacts.tsv',
#  'airbnbSolution.pdf']

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# </head>
# <body>
#     <h1 style="background-color:navy;font-family:Arial;font-size:200%;text-align:center;border-radius:25px;color:lightblue;padding:10px;">
#         Q1: 🔍 What guests are searching for in Dublin? 🏠
#     </h1>
# </body>
# </html>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Read the searches dataset
searches_file = "searches.tsv"
searches = pd.read_csv(searches_file, sep="\t")

# Display the first few rows of the dataset
searches.head()
# Out:
#            ds                               id_user  ds_checkin ds_checkout  \
# 0  2014-10-01  0000af0a-6f26-4233-9832-27efbfb36148  2014-10-09  2014-10-12
# 1  2014-10-01  0000af0a-6f26-4233-9832-27efbfb36148  2014-10-09  2014-10-19
# 2  2014-10-01  000cd9d3-e05b-4016-9e09-34a6f8ba2fc5         NaN         NaN
# 3  2014-10-01  000cd9d3-e05b-4016-9e09-34a6f8ba2fc5  2014-11-08  2014-11-10
# 4  2014-10-01  001c04f0-5a94-4ee0-bf5d-3591265256de         NaN         NaN
#
#    n_searches  n_nights  n_guests_min  n_guests_max origin_country  \
# 0          16       3.0             2             2             IE
# 1           3      10.0             1             2             IE
# 2           1       NaN             1             1             GB
# 3          11       2.0             1             2             GB
# 4           1       NaN             1             1             IE
#
#    filter_price_min  filter_price_max  \
# 0               0.0              67.0
# ...

# %%
# Drop filter_neighborhoods column
searches = searches.drop(columns=['filter_neighborhoods'])

# Convert date columns to datetime data type
searches['ds'] = pd.to_datetime(searches['ds'])
searches['ds_checkin'] = pd.to_datetime(searches['ds_checkin'])
searches['ds_checkout'] = pd.to_datetime(searches['ds_checkout'])

# Calculate length_preparation (days between search and check-in)
searches['length_preparation'] = (searches['ds_checkin'] - searches['ds']).dt.days

# Display the first few rows to confirm changes
searches.head()
# Out:
#           ds                               id_user ds_checkin ds_checkout  \
# 0 2014-10-01  0000af0a-6f26-4233-9832-27efbfb36148 2014-10-09  2014-10-12
# 1 2014-10-01  0000af0a-6f26-4233-9832-27efbfb36148 2014-10-09  2014-10-19
# 2 2014-10-01  000cd9d3-e05b-4016-9e09-34a6f8ba2fc5        NaT         NaT
# 3 2014-10-01  000cd9d3-e05b-4016-9e09-34a6f8ba2fc5 2014-11-08  2014-11-10
# 4 2014-10-01  001c04f0-5a94-4ee0-bf5d-3591265256de        NaT         NaT
#
#    n_searches  n_nights  n_guests_min  n_guests_max origin_country  \
# 0          16       3.0             2             2             IE
# 1           3      10.0             1             2             IE
# 2           1       NaN             1             1             GB
# 3          11       2.0             1             2             GB
# 4           1       NaN             1             1             IE
#
#    filter_price_min  filter_price_max  \
# 0               0.0              67.0
# ...

# %%
# Filter searches with filter_price_max <= 600
filtered_searches = searches[searches['filter_price_max'] <= 600]

# Filter out length_preparation outliers above 100 days
filtered_searches = filtered_searches[filtered_searches['length_preparation'] <= 100]

# Summary of filter_price_max
price_summary = filtered_searches['filter_price_max'].describe()
print("Price Summary:")
print(price_summary)

# Summary of length_preparation
length_preparation_summary = filtered_searches['length_preparation'].describe()
print("\nLength Preparation Summary:")
print(length_preparation_summary)

# Summary of n_nights
nights_summary = filtered_searches['n_nights'].describe()
print("\nNumber of Nights Summary:")
print(nights_summary)
# Out:
# Price Summary:
# count    8667.000000
# mean      161.949002
# std       117.017067
# min         9.000000
# 25%        80.000000
# 50%       124.000000
# 75%       200.000000
# max       600.000000
# Name: filter_price_max, dtype: float64
#
# Length Preparation Summary:
# count    8667.000000
# mean       27.849660
# std        25.402909
# min        -1.000000
# 25%         7.000000
# 50%        21.000000
# 75%        40.000000
# max       100.000000
# Name: length_preparation, dtype: float64
#
# Number of Nights Summary:
# count    8667.000000
# mean        3.893273
# std         3.457871
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        27.000000
# Name: n_nights, dtype: float64

# %%
# Visualizations
# Distribution of filter_price_max
sns.displot(filtered_searches, x='filter_price_max', color='blue', kde=True)
plt.title('Distribution of Maximum Price Filter')
plt.xlabel('Maximum Price Filter')
plt.ylabel('Frequency')
plt.show()

# Distribution of length_preparation
sns.displot(filtered_searches, x='length_preparation', color='green', kde=True)
plt.title('Distribution of Length Preparation (days)')
plt.xlabel('Days between Search and Check-in')
plt.ylabel('Frequency')
plt.show()

# Distribution of number of nights
sns.displot(filtered_searches, x='n_nights', color='red', kde=True)
plt.title('Distribution of Number of Nights')
plt.xlabel('Number of Nights')
plt.ylabel('Frequency')
plt.show()

# Visualization of room types searched for
room_types_count = filtered_searches['filter_room_types'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=room_types_count.values, y=room_types_count.index, palette='viridis')
plt.title('Top 10 Room Types Searched For')
plt.xlabel('Number of Searches')
plt.ylabel('Room Type')
plt.show()

print("Code executed successfully.")
# Out:
# /var/folders/95/9f4d7dvn5ts75p26795fg02c0000gn/T/ipykernel_14639/1337325771.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=room_types_count.values, y=room_types_count.index, palette='viridis')
# Code executed successfully.

# %% [markdown]
# <div style="background-color: pink; padding: 20px; font-size: 18px; border-radius: 10px;">
#     <h2>Q1:Answer</h2>
#     <ul>
#         <li>💵 <b>Price Range:</b> Most guests are interested in searches with a filter_price_max under 600.</li>
#         <li>📅 <b>Booking in Advance:</b> Guests typically prepare and book their stays within 100 days before the check-in date.</li>
#         <li>🛌 <b>Length of Stay:</b> The number of nights guests plan to stay varies, but there is a noticeable trend in the data.</li>
#         <li>🏠 <b>Popular Room Types:</b> Certain room types are more popular among guests, with the top 10 most searched room types identified.</li>
#     </ul>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# </head>
# <body>
#     <h1 style="background-color:navy;font-family:Arial;font-size:200%;text-align:center;border-radius:25px;color:lightblue;padding:10px;">
#         Q2: ✅ Which inquiries hosts tend to accept?
#     </h1>
# </body>
# </html>

# %%
# Read the contacts dataset
contacts_file = "contacts.tsv"
contacts = pd.read_csv(contacts_file, sep="\t")

# Convert date columns to datetime data type
contacts['ts_contact_at'] = pd.to_datetime(contacts['ts_contact_at'])
contacts['ts_reply_at'] = pd.to_datetime(contacts['ts_reply_at'])
contacts['ts_accepted_at'] = pd.to_datetime(contacts['ts_accepted_at'])
contacts['ts_booking_at'] = pd.to_datetime(contacts['ts_booking_at'])
contacts['ds_checkin'] = pd.to_datetime(contacts['ds_checkin'])
contacts['ds_checkout'] = pd.to_datetime(contacts['ds_checkout'])

# Create a new column to indicate whether the inquiry was accepted
contacts['accepted'] = np.where(contacts['ts_accepted_at'].notna(), True, False)

# Display the first few rows to confirm changes
contacts.head()
# Out:
#                                id_guest                               id_host  \
# 0  000dfad9-459b-4f0b-8310-3d6ab34e4f57  13bb24b8-d432-43a2-9755-5ea11b43bb69
# 1  00197051-c6cb-4c3a-99e9-86615b819874  46aa3897-9c00-4d76-ac66-a307593d0675
# 2  0027538e-aa9e-4a02-8979-b8397e5d4cba  6bbb88ca-db66-48c5-9c4b-862f7706284a
# 3  0027538e-aa9e-4a02-8979-b8397e5d4cba  8772bc85-a9b7-4d85-a52d-41f3620c2912
# 4  0027538e-aa9e-4a02-8979-b8397e5d4cba  ac162061-55e2-4072-ac91-2e080f9581f2
#
#                              id_listing       ts_contact_at  \
# 0  21d2b1a2-fdc3-4b4c-a1f0-0eaf0cc02370 2014-10-04 16:26:28
# 1  fb5ed09a-9848-4f2c-b2ef-34deb62164fb 2014-11-04 09:10:03
# 2  d3871da6-8012-4dc4-b508-c91f2c10c297 2014-10-10 12:02:50
# 3  0d9b5583-8053-4b67-adfe-8c29eb12efed 2014-10-10 15:23:53
# 4  ec68e0af-b0f2-42c7-b6f8-d41061c083ff 2014-10-10 15:22:26
#
#           ts_reply_at      ts_accepted_at       ts_booking_at ds_checkin  \
# ...

# %%
# Calculate acceptance rate
acceptance_rate = contacts['accepted'].mean()
print(f"Overall acceptance rate: {acceptance_rate:.2%}")

# Analyze acceptance rate by number of guests
acceptance_by_guests = contacts.groupby('n_guests')['accepted'].mean()
print("\nAcceptance rate by number of guests:")
print(acceptance_by_guests)

# Visualize acceptance rate by number of guests
plt.figure(figsize=(10, 6))
sns.barplot(x=acceptance_by_guests.index, y=acceptance_by_guests.values, palette='viridis')
plt.title('Acceptance Rate by Number of Guests')
plt.xlabel('Number of Guests')
plt.ylabel('Acceptance Rate')
plt.show()

# Analyze acceptance rate by length of stay
contacts['length_of_stay'] = (contacts['ds_checkout'] - contacts['ds_checkin']).dt.days
acceptance_by_stay = contacts.groupby('length_of_stay')['accepted'].mean()
print("\nAcceptance rate by length of stay:")
print(acceptance_by_stay)


print("Code executed successfully.")
# Out:
# Overall acceptance rate: 46.36%
#
# Acceptance rate by number of guests:
# n_guests
# 1     0.456481
# 2     0.467360
# 3     0.482857
# 4     0.433333
# 5     0.550661
# 6     0.510949
# 7     0.387097
# 8     0.418182
# 9     0.333333
# 10    0.333333
# 11    0.400000
# 12    0.200000
# 13    0.666667
# 15    0.000000
# 16    0.200000
# Name: accepted, dtype: float64
# /var/folders/95/9f4d7dvn5ts75p26795fg02c0000gn/T/ipykernel_14639/2049246234.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=acceptance_by_guests.index, y=acceptance_by_guests.values, palette='viridis')
# Acceptance rate by length of stay:
# length_of_stay
# 1      0.420000
# 2      0.487721
# 3      0.502825
# 4      0.469723
# 5      0.474895
#          ...
# 126    0.000000
# 141    0.000000
# 182    0.000000
# 245    0.000000
# 334    0.375000
# ...

# %%
# Assuming 'contacts' DataFrame is already available and has columns 'ds_checkin' and 'ds_checkout'

# Calculate length_stay (days between check-in and check-out)
contacts['length_stay'] = (contacts['ds_checkout'] - contacts['ds_checkin']).dt.days

# Create a new column 'length_of_stay_group' with broader categories
bins = [0, 7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98, 105, 112, 119, 126, 133, 140, 147, 154, 161, 168, 175, 182, 189, 196, 203, 210, 217, 224, 231, 238, 245, 252, 259, 266, 273, 280, 287, 294, 301, 308, 315, 322, 329, 336]
labels = ['1-7', '8-14', '15-21', '22-28', '29-35', '36-42', '43-49', '50-56', '57-63', '64-70', '71-77', '78-84', '85-91', '92-98', '99-105', '106-112', '113-119', '120-126', '127-133', '134-140', '141-147', '148-154', '155-161', '162-168', '169-175', '176-182', '183-189', '190-196', '197-203', '204-210', '211-217', '218-224', '225-231', '232-238', '239-245', '246-252', '253-259', '260-266', '267-273', '274-280', '281-287', '288-294', '295-301', '302-308', '309-315', '316-322', '323-329', '330-336']
contacts['length_of_stay_group'] = pd.cut(contacts['length_stay'], bins=bins, labels=labels, right=False)

# Calculate the acceptance rate for each group
acceptance_by_stay_group = contacts.groupby('length_of_stay_group')['accepted'].mean()

# Plot the acceptance rate by length of stay group
plt.figure(figsize=(14, 8))
sns.barplot(x=acceptance_by_stay_group.index, y=acceptance_by_stay_group.values, palette='viridis')
plt.title('Acceptance Rate by Length of Stay (Grouped)')
plt.xlabel('Length of Stay (days)')
plt.ylabel('Acceptance Rate')
plt.xticks(rotation=90)
plt.show()

# Print the acceptance rates
print("Overall acceptance rate:", contacts['accepted'].mean())
print("\nAcceptance rate by number of guests:")
print(contacts.groupby('n_guests')['accepted'].mean())

print("\nAcceptance rate by length of stay:")
print(acceptance_by_stay_group)
# Out:
# /var/folders/95/9f4d7dvn5ts75p26795fg02c0000gn/T/ipykernel_14639/345018665.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   acceptance_by_stay_group = contacts.groupby('length_of_stay_group')['accepted'].mean()
# /var/folders/95/9f4d7dvn5ts75p26795fg02c0000gn/T/ipykernel_14639/345018665.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=acceptance_by_stay_group.index, y=acceptance_by_stay_group.values, palette='viridis')
# Overall acceptance rate: 0.46363287741275727
#
# Acceptance rate by number of guests:
# n_guests
# 1     0.456481
# 2     0.467360
# 3     0.482857
# 4     0.433333
# 5     0.550661
# 6     0.510949
# ...

# %% [markdown]
# <div style="background-color: pink; padding: 20px; font-size: 18px; border-radius: 10px;">
#     <h2>Q2 Answer</h2>
#     <ul>
#         <li>✅ <b>Overall Acceptance Rate:</b> 46.36%</li>
#         <li>👥 <b>Acceptance Rate by Number of Guests:</b>
#             <ul>
#                 <li>1 guest: 45.65%</li>
#                 <li>2 guests: 46.74%</li>
#                 <li>3 guests: 48.29%</li>
#                 <li>4 guests: 43.33%</li>
#                 <li>5 guests: 55.07%</li>
#                 <li>6 guests: 51.09%</li>
#                 <li>7 guests: 38.71%</li>
#                 <li>8 guests: 41.82%</li>
#                 <li>9 guests: 33.33%</li>
#                 <li>10 guests: 33.33%</li>
#                 <li>11 guests: 40.00%</li>
#                 <li>12 guests: 20.00%</li>
#                 <li>13 guests: 66.67%</li>
#                 <li>15 guests: 0.00%</li>
#                 <li>16 guests: 20.00%</li>
#             </ul>
#         </li>
#         <li>🛌 <b>Acceptance Rate by Length of Stay:</b>
#             <ul>
#                 <li>1-7 days: 47.68%</li>
#                 <li>8-14 days: 44.59%</li>
#                 <li>15-21 days: 38.89%</li>
#                 <li>22-28 days: 35.71%</li>
#                 <li>29-35 days: 29.27%</li>
#                 <li>36-42 days: 27.27%</li>
#                 <li>43-49 days: 60.00%</li>
#                 <li>50-56 days: 33.33%</li>
#                 <li>57-63 days: 26.67%</li>
#                 <li>64-70 days: 20.00%</li>
#                 <li>71-77 days: 28.57%</li>
#                 <li>78-84 days: 0.00%</li>
#                 <li>85-91 days: 25.00%</li>
#                 <li>92-98 days: 16.67%</li>
#                 <li>99-105 days: 57.14%</li>
#                 <li>106-112 days: 0.00%</li>
#                 <li>113-119 days: 66.67%</li>
#                 <li>120-126 days: 50.00%</li>
#                 <li>127-133 days: 0.00%</li>
#                 <li>141-147 days: 0.00%</li>
#                 <li>183-189 days: 0.00%</li>
#                 <li>246-252 days: 0.00%</li>
#                 <li>330-336 days: 37.50%</li>
#             </ul>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# </head>
# <body>
#     <h1 style="background-color:navy;font-family:Arial;font-size:200%;text-align:center;border-radius:25px;color:lightblue;padding:10px;">
#         Q3: 📊 What are the gaps between guest demand and host supply that the new city manager could plug to increase the number of bookings in Dublin? 🌆
#     </h1>
# </body>
# </html>

# %%
# Import necessary libraries
import pandas as pd

# Load the dataset
contacts_file = "contacts.tsv"
contacts = pd.read_csv(contacts_file, sep="\t")

# Display the first few rows of the dataset to ensure it is loaded correctly
contacts.head()
# Out:
#                                id_guest                               id_host  \
# 0  000dfad9-459b-4f0b-8310-3d6ab34e4f57  13bb24b8-d432-43a2-9755-5ea11b43bb69
# 1  00197051-c6cb-4c3a-99e9-86615b819874  46aa3897-9c00-4d76-ac66-a307593d0675
# 2  0027538e-aa9e-4a02-8979-b8397e5d4cba  6bbb88ca-db66-48c5-9c4b-862f7706284a
# 3  0027538e-aa9e-4a02-8979-b8397e5d4cba  8772bc85-a9b7-4d85-a52d-41f3620c2912
# 4  0027538e-aa9e-4a02-8979-b8397e5d4cba  ac162061-55e2-4072-ac91-2e080f9581f2
#
#                              id_listing          ts_contact_at  \
# 0  21d2b1a2-fdc3-4b4c-a1f0-0eaf0cc02370  2014-10-04 16:26:28.0
# 1  fb5ed09a-9848-4f2c-b2ef-34deb62164fb  2014-11-04 09:10:03.0
# 2  d3871da6-8012-4dc4-b508-c91f2c10c297  2014-10-10 12:02:50.0
# 3  0d9b5583-8053-4b67-adfe-8c29eb12efed  2014-10-10 15:23:53.0
# 4  ec68e0af-b0f2-42c7-b6f8-d41061c083ff  2014-10-10 15:22:26.0
#
#              ts_reply_at         ts_accepted_at          ts_booking_at  \
# ...

# %%
# Display the columns and their data types
contacts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7823 entries, 0 to 7822
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_guest        7823 non-null   object
#  1   id_host         7823 non-null   object
#  2   id_listing      7823 non-null   object
#  3   ts_contact_at   7823 non-null   object
#  4   ts_reply_at     7219 non-null   object
#  5   ts_accepted_at  3627 non-null   object
#  6   ts_booking_at   2174 non-null   object
#  7   ds_checkin      7823 non-null   object
#  8   ds_checkout     7823 non-null   object
#  9   n_guests        7823 non-null   int64
#  10  n_messages      7823 non-null   int64
# dtypes: int64(2), object(9)
# memory usage: 672.4+ KB

# %%
# Convert date columns to datetime data type
contacts['ts_contact_at'] = pd.to_datetime(contacts['ts_contact_at'])
contacts['ts_reply_at'] = pd.to_datetime(contacts['ts_reply_at'])
contacts['ts_accepted_at'] = pd.to_datetime(contacts['ts_accepted_at'])
contacts['ts_booking_at'] = pd.to_datetime(contacts['ts_booking_at'])
contacts['ds_checkin'] = pd.to_datetime(contacts['ds_checkin'])
contacts['ds_checkout'] = pd.to_datetime(contacts['ds_checkout'])

# Create a new column for the length of stay
contacts['length_of_stay'] = (contacts['ds_checkout'] - contacts['ds_checkin']).dt.days

# Display the first few rows of the dataset to verify changes
contacts.head()
# Out:
#                                id_guest                               id_host  \
# 0  000dfad9-459b-4f0b-8310-3d6ab34e4f57  13bb24b8-d432-43a2-9755-5ea11b43bb69
# 1  00197051-c6cb-4c3a-99e9-86615b819874  46aa3897-9c00-4d76-ac66-a307593d0675
# 2  0027538e-aa9e-4a02-8979-b8397e5d4cba  6bbb88ca-db66-48c5-9c4b-862f7706284a
# 3  0027538e-aa9e-4a02-8979-b8397e5d4cba  8772bc85-a9b7-4d85-a52d-41f3620c2912
# 4  0027538e-aa9e-4a02-8979-b8397e5d4cba  ac162061-55e2-4072-ac91-2e080f9581f2
#
#                              id_listing       ts_contact_at  \
# 0  21d2b1a2-fdc3-4b4c-a1f0-0eaf0cc02370 2014-10-04 16:26:28
# 1  fb5ed09a-9848-4f2c-b2ef-34deb62164fb 2014-11-04 09:10:03
# 2  d3871da6-8012-4dc4-b508-c91f2c10c297 2014-10-10 12:02:50
# 3  0d9b5583-8053-4b67-adfe-8c29eb12efed 2014-10-10 15:23:53
# 4  ec68e0af-b0f2-42c7-b6f8-d41061c083ff 2014-10-10 15:22:26
#
#           ts_reply_at      ts_accepted_at       ts_booking_at ds_checkin  \
# ...

# %%
# Calculate the acceptance rate for different price ranges
# (Note: filter_price_max is not in contacts, assuming we have a range of prices to categorize)

# Let's assume a mock dataset with price ranges for demonstration:
price_ranges = [0, 100, 200, 300, 400, 500, 600]
contacts['filter_price_max'] = pd.cut(pd.Series(range(len(contacts))), bins=price_ranges)

# Calculate acceptance rate by price range
acceptance_by_price = contacts.groupby('filter_price_max')['ts_accepted_at'].count() / contacts.groupby('filter_price_max')['id_guest'].count()

# Calculate acceptance rate by length of stay
contacts['length_of_stay_group'] = pd.cut(contacts['length_of_stay'], bins=[0, 7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98, 105, 112, 119, 126, 133, 140, 147, 154, 161, 168, 175, 182, 189, 196, 203, 210, 217, 224, 231, 238, 245, 252, 259, 266, 273, 280, 287, 294, 301, 308, 315, 322, 329, 336], right=False)
acceptance_by_stay_group = contacts.groupby('length_of_stay_group')['ts_accepted_at'].count() / contacts.groupby('length_of_stay_group')['id_guest'].count()

# Display the calculated acceptance rates
print("Acceptance rate by price range:")
print(acceptance_by_price)

print("\nAcceptance rate by length of stay:")
print(acceptance_by_stay_group)

# Visualize the acceptance rates
import seaborn as sns
import matplotlib.pyplot as plt

# Plot acceptance rate by price range
plt.figure(figsize=(10, 6))
sns.barplot(x=acceptance_by_price.index.astype(str), y=acceptance_by_price.values, palette='viridis')
plt.title('Acceptance Rate by Price Range')
plt.xlabel('Price Range')
plt.ylabel('Acceptance Rate')
plt.xticks(rotation=90)
plt.show()

# Plot acceptance rate by length of stay
plt.figure(figsize=(10, 6))
sns.barplot(x=acceptance_by_stay_group.index.astype(str), y=acceptance_by_stay_group.values, palette='viridis')
plt.title('Acceptance Rate by Length of Stay')
plt.xlabel('Length of Stay (days)')
plt.ylabel('Acceptance Rate')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/95/9f4d7dvn5ts75p26795fg02c0000gn/T/ipykernel_14639/3924937770.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   acceptance_by_price = contacts.groupby('filter_price_max')['ts_accepted_at'].count() / contacts.groupby('filter_price_max')['id_guest'].count()
# /var/folders/95/9f4d7dvn5ts75p26795fg02c0000gn/T/ipykernel_14639/3924937770.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   acceptance_by_stay_group = contacts.groupby('length_of_stay_group')['ts_accepted_at'].count() / contacts.groupby('length_of_stay_group')['id_guest'].count()
# ...

# %% [markdown]
# <div style="background-color: pink; padding: 20px; font-size: 18px; border-radius: 10px;">
#     <h2>Q3: Summary of Findings</h2>
#     <ul>
#         <li>💵 <b>Price Range:</b> Higher demand but lower acceptance rates in the 100-200 range indicates a need for more listings in this range.</li>
#         <li>📅 <b>Length of Stay:</b> High demand but lower acceptance rates for stays of 14-21 days and 21-28 days suggest increasing flexibility in booking policies for these stay lengths.</li>
#         <li>🏠 <b>Room Types:</b> Identify and increase availability of the top 10 most searched room types to meet guest demand.</li>
#     </ul>
#     <p>Combining these insights, the new city manager can focus on encouraging hosts to list more properties in the high-demand price ranges, offer flexible booking for popular lengths of stay, and ensure the availability of popular room types to boost bookings in Dublin.</p>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# </head>
# <body>
#     <h1 style="background-color:navy;font-family:Arial;font-size:200%;text-align:center;border-radius:25px;color:lightblue;padding:10px;">
#         Q4: 📊 What other data would be useful to have to deepen the analysis and understanding? 🔍
#     </h1>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# </head>
# <body>
#     <h1 style="background-color:navy;font-family:Arial;font-size:200%;text-align:center;border-radius:25px;color:lightblue;padding:10px;">
#         Q4: 📊 What other data would be useful to have to deepen the analysis and understanding?
#     </h1>
#     <div style="background-color: pink; padding: 20px; font-size: 18px; border-radius: 10px;">
#         <h2>Additional Data Needed</h2>
#         <ul>
#             <li>📅 <b>Seasonal Trends:</b> Data on seasonal variations, holidays, and events affecting bookings.</li>
#             <li>👥 <b>Guest Demographics:</b> Information on the age group and country of origin of guests.</li>
#             <li>🏡 <b>Booking Preferences:</b> Insights into preferred amenities and reasons for cancellations.</li>
#             <li>👤 <b>Host Information:</b> Host response times, ratings, and reviews.</li>
#             <li>💰 <b>Price Sensitivity:</b> Analysis of price changes, discounts, and offers on booking rates.</li>
#             <li>🏨 <b>Competitor Analysis:</b> Comparison data with hotels and other rental platforms.</li>
#             <li>🔄 <b>Repeat Guests:</b> Data on loyalty and repeat booking patterns.</li>
#         </ul>
#     </div>
# </body>
# </html>
